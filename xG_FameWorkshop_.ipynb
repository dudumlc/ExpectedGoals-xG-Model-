# %% [markdown]
# # xG

# %%
! pip install gandula
# Out:
# Requirement already satisfied: gandula in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (0.1.1)
# Requirement already satisfied: aiohttp>=3.10.5 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (3.10.5)
# Requirement already satisfied: gql>=3.5.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (3.5.0)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (1.1.1)
# Requirement already satisfied: matplotlib>=3.9.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (3.9.2)
# Requirement already satisfied: mplsoccer>=1.4.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (1.4.0)
# Requirement already satisfied: pandas>=2.2.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (2.2.2)
# Requirement already satisfied: pydantic>=2.8.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (2.8.2)
# Requirement already satisfied: ruff>=0.6.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (0.6.3)
# Requirement already satisfied: scikit-learn>=1.5.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (1.5.1)
# Requirement already satisfied: tqdm>=4.66.5 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gandula) (4.66.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from aiohttp>=3.10.5->gandula) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from aiohttp>=3.10.5->gandula) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from aiohttp>=3.10.5->gandula) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from aiohttp>=3.10.5->gandula) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from aiohttp>=3.10.5->gandula) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from aiohttp>=3.10.5->gandula) (1.9.7)
# Requirement already satisfied: graphql-core<3.3,>=3.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gql>=3.5.0->gandula) (3.2.3)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gql>=3.5.0->gandula) (2.2.1)
# Requirement already satisfied: anyio<5,>=3.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from gql>=3.5.0->gandula) (4.4.0)
# Requirement already satisfied: notebook in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter>=1.0.0->gandula) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter>=1.0.0->gandula) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter>=1.0.0->gandula) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter>=1.0.0->gandula) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter>=1.0.0->gandula) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter>=1.0.0->gandula) (4.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (1.4.6)
# Requirement already satisfied: numpy>=1.23 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from matplotlib>=3.9.2->gandula) (2.9.0.post0)
# Requirement already satisfied: requests in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from mplsoccer>=1.4.0->gandula) (2.32.3)
# Requirement already satisfied: scipy in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from mplsoccer>=1.4.0->gandula) (1.14.1)
# Requirement already satisfied: seaborn in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from mplsoccer>=1.4.0->gandula) (0.13.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from pandas>=2.2.2->gandula) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from pandas>=2.2.2->gandula) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from pydantic>=2.8.2->gandula) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from pydantic>=2.8.2->gandula) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from pydantic>=2.8.2->gandula) (4.12.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from scikit-learn>=1.5.1->gandula) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from scikit-learn>=1.5.1->gandula) (3.5.0)
# Requirement already satisfied: colorama in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from tqdm>=4.66.5->gandula) (0.4.6)
# Requirement already satisfied: idna>=2.8 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from anyio<5,>=3.0->gql>=3.5.0->gandula) (3.8)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from anyio<5,>=3.0->gql>=3.5.0->gandula) (1.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.9.2->gandula) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (1.6.0)
# Requirement already satisfied: psutil in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipykernel->jupyter>=1.0.0->gandula) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipywidgets->jupyter>=1.0.0->gandula) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipywidgets->jupyter>=1.0.0->gandula) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-console->jupyter>=1.0.0->gandula) (3.0.47)
# Requirement already satisfied: pygments in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-console->jupyter>=1.0.0->gandula) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab->jupyter>=1.0.0->gandula) (65.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbconvert->jupyter>=1.0.0->gandula) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from requests->mplsoccer>=1.4.0->gandula) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from requests->mplsoccer>=1.4.0->gandula) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from requests->mplsoccer>=1.4.0->gandula) (2024.8.30)
# Requirement already satisfied: webencodings in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->gandula) (0.5.1)
# Requirement already satisfied: httpcore==1.* in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->gandula) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter>=1.0.0->gandula) (0.14.0)
# Requirement already satisfied: decorator in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->gandula) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter>=1.0.0->gandula) (306)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->gandula) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter>=1.0.0->gandula) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->gandula) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (0.1.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->gandula) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter>=1.0.0->gandula) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\dudu_\onedrive\documentos\estudos\3. workshop fame - xg\0. competição\famexg\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter>=1.0.0->gandula) (2.9.0.20240821)
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Esse notebook mostra como implementar um modelo de Expectativa de Gols do zero até ter ele completo.

# %% [markdown]
# ## Imports

# %%
import gandula

# %%
gandula
# Out:
# <module 'gandula' from 'c:\\Users\\Dudu_\\OneDrive\\Documentos\\Estudos\\3. Workshop FAME - xG\\0. Competição\\famexG\\Lib\\site-packages\\gandula\\__init__.py'>

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Coleta de dados

# %% [markdown]
# A PFF fornece dois tipos de dado, que podem vir de jeitos diferentes:
#
# - dados de evento: json ou via API
# - dados de tracking: json

# %% [markdown]
# O dado de todos os chutes de todas as partidas do dataset foi pre-processado para facilitar nossas vida. Em outros notebooks da biblioteca, você pode checar como ele foi gerado. Podemos extraí-lo da seguinte forma:

# %%
shot_frames = gandula.loader.read_pickle(
    'C:\\Users\\Dudu_\\OneDrive\\Documentos\\Estudos\\3. Workshop FAME - xG\\0. Competição\\enhaced_frames_shots.pkl'
)

# %% [markdown]
# ## Exploração dos dados

# %% [markdown]
# Vamos primeiro ver como os chutes aparecem.

# %%
type(shot_frames)
# Out:
# list

# %% [markdown]
# Se é uma lista vamos ver com os chutes aparecem.

# %%
shot_frames[:5]
# Out:
# [{'frame': Frame 9282 - 130.66371,
#   'event': PFF_PossessionEventType.SHOT=6511176},
#  {'frame': Frame 20398 - 501.567947,
#   'event': PFF_PossessionEventType.SHOT=6512525},
#  {'frame': Frame 22485 - 571.20425,
#   'event': PFF_PossessionEventType.SHOT=6511957},
#  {'frame': Frame 36063 - 1024.257303,
#   'event': PFF_PossessionEventType.SHOT=6511049},
#  {'frame': Frame 41923 - 1219.786165,
#   'event': PFF_PossessionEventType.SHOT=6511298}]

# %% [markdown]
# ## Tratamento dos dados

# %% [markdown]
# No modelo de xG que vamos desenvolver aqui, vamos precisar extrair o ângulo para o gol e a distância. Além disso, é necessário saber se o chute resultou em gol ou não. Vamos gerar esses dados para cada chute.

# %% [markdown]
# Para facilitar os cálculos, vou transformar os dados gerados pelo gandula em um dataframe.

# %%
data = [
    {
        'event_id': frame['frame'].event_id,
        'frame_id': frame['frame'].frame_id,
        'x': frame['event'].shootingEvent.shotPointX,
        'y': frame['event'].shootingEvent.shotPointY,
        'outcome': frame['event'].shootingEvent.shotOutcomeType,
        'body_part': frame['event'].shootingEvent.shotBodyType,
        'set_piece': frame['frame'].event.setpiece_type,
        'initial_height_type':frame['event'].shootingEvent.shotInitialHeightType,
        'pressureType': frame['event'].shootingEvent.pressureType,
        'shotNatureType': frame['event'].shootingEvent.shotNatureType
    }
    for frame in shot_frames
]

df = pd.DataFrame(data)
df = (
    df.drop_duplicates()
)  # TODO: fix enhanced shot frames: there shouldn't be duplicates
df.head()
# Out:
#    event_id  frame_id       x       y                     outcome  \
# 0   6629878      9282 -40.281  -4.868   ShotOutcomeType.ON_TARGET
# 1   6631191     20398  20.974 -12.711  ShotOutcomeType.OFF_TARGET
# 2   6630642     22485  16.634 -13.580        ShotOutcomeType.GOAL
# 3   6629751     36063  15.746  14.719  ShotOutcomeType.OFF_TARGET
# 4   6630005     41923  -4.834 -21.644  ShotOutcomeType.OFF_TARGET
#
#              body_part set_piece          initial_height_type  \
# 0   BodyType.LEFT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 1  BodyType.RIGHT_FOOT      None         ShotHeightType.SHORT
# 2  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 3   BodyType.LEFT_FOOT      None          ShotHeightType.OVER
# 4  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
#
#              pressureType            shotNatureType
# 0                    None  ShotNatureType.PLACEMENT
# 1  PressureType.PRESSURED      ShotNatureType.POWER
# 2                    None  ShotNatureType.PLACEMENT
# 3                    None  ShotNatureType.PLACEMENT
# 4                    None  ShotNatureType.PLACEMENT

# %%
df.shape
# Out:
# (1518, 10)

# %% [markdown]
# Para extrair a distância, vamos utilizar a distância euclideana. Para fazer o cálculo, precisamos considerar que os chutes podem sair dos dois lados do campo. A PFF tem como padrão nos seus dados direcionar o campo de acordo com o que a câmera mostra na transmissão. Além disso, as coordenadas são centralizadas no meio de campo. Vamos assumir que os atacantes estão sempre no campo adversário para chutar. Com isso, conseguimos extrair corretamente o dado.

# %% [markdown]
# Iremos setar como padrão que o time que está chutando ataca sempre da direita para a esquerda, para facilitar o cálculo. Isso quer dizer que o centro do gol está sempre na coordenada y = 0 e x = 52.5.

# %%
# espelhando chutes com x negativo
df.loc[df['x'] < 0, 'y'] = df.loc[df['x'] < 0, 'y'] * -1
df.loc[df['x'] < 0, 'x'] = df.loc[df['x'] < 0, 'x'] * -1

# calculando a distância do chute para o gol
df['dist'] = np.sqrt((df['x'] - 52.5) ** 2 + (df['y'] - 0) ** 2)

df.head()
# Out:
#    event_id  frame_id       x       y                     outcome  \
# 0   6629878      9282  40.281   4.868   ShotOutcomeType.ON_TARGET
# 1   6631191     20398  20.974 -12.711  ShotOutcomeType.OFF_TARGET
# 2   6630642     22485  16.634 -13.580        ShotOutcomeType.GOAL
# 3   6629751     36063  15.746  14.719  ShotOutcomeType.OFF_TARGET
# 4   6630005     41923   4.834  21.644  ShotOutcomeType.OFF_TARGET
#
#              body_part set_piece          initial_height_type  \
# 0   BodyType.LEFT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 1  BodyType.RIGHT_FOOT      None         ShotHeightType.SHORT
# 2  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 3   BodyType.LEFT_FOOT      None          ShotHeightType.OVER
# 4  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
#
#              pressureType            shotNatureType       dist
# 0                    None  ShotNatureType.PLACEMENT  13.152999
# 1  PressureType.PRESSURED      ShotNatureType.POWER  33.992031
# 2                    None  ShotNatureType.PLACEMENT  38.350833
# 3                    None  ShotNatureType.PLACEMENT  39.591735
# 4                    None  ShotNatureType.PLACEMENT  52.349883

# %% [markdown]
# Para extrair o ângulo, precisamos pensar na geometria do chute.
# Para calcular o ângulo do gol, θ, tomamos a coordenada (x,y) do chute
# - x é a distância ao longo da borda do campo desde a linha do gol;
# - y é a distância do meio do campo.
# - (0,0) é o ponto na linha de fundo no meio do gol.
# O ângulo entre dois vetores que apontam para as traves é:
# $$
# \tan(\theta) = \frac{7.32x}{x^2 + y^2 - \left(\frac{7.32}{2}\right)^2}
# $$
# - onde 7.32 é o tamanho do gol.

# %%
df['ang'] = np.arctan((7.32 * df['x']) / (df['x'] ** 2 + (7.32 - df['y']) ** 2))

df.head()
# Out:
#    event_id  frame_id       x       y                     outcome  \
# 0   6629878      9282  40.281   4.868   ShotOutcomeType.ON_TARGET
# 1   6631191     20398  20.974 -12.711  ShotOutcomeType.OFF_TARGET
# 2   6630642     22485  16.634 -13.580        ShotOutcomeType.GOAL
# 3   6629751     36063  15.746  14.719  ShotOutcomeType.OFF_TARGET
# 4   6630005     41923   4.834  21.644  ShotOutcomeType.OFF_TARGET
#
#              body_part set_piece          initial_height_type  \
# 0   BodyType.LEFT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 1  BodyType.RIGHT_FOOT      None         ShotHeightType.SHORT
# 2  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 3   BodyType.LEFT_FOOT      None          ShotHeightType.OVER
# 4  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
#
#              pressureType            shotNatureType       dist       ang
# 0                    None  ShotNatureType.PLACEMENT  13.152999  0.179112
# 1  PressureType.PRESSURED      ShotNatureType.POWER  33.992031  0.180536
# 2                    None  ShotNatureType.PLACEMENT  38.350833  0.169025
# 3                    None  ShotNatureType.PLACEMENT  39.591735  0.363845
# 4                    None  ShotNatureType.PLACEMENT  52.349883  0.153607

# %% [markdown]
# Por fim, vamos extrai quando temos um gol e quando não.

# %%
df['gol'] = df['outcome'] == gandula.providers.pff.schema.event.ShotOutcomeType.GOAL
df.head()
# Out:
#    event_id  frame_id       x       y                     outcome  \
# 0   6629878      9282  40.281   4.868   ShotOutcomeType.ON_TARGET
# 1   6631191     20398  20.974 -12.711  ShotOutcomeType.OFF_TARGET
# 2   6630642     22485  16.634 -13.580        ShotOutcomeType.GOAL
# 3   6629751     36063  15.746  14.719  ShotOutcomeType.OFF_TARGET
# 4   6630005     41923   4.834  21.644  ShotOutcomeType.OFF_TARGET
#
#              body_part set_piece          initial_height_type  \
# 0   BodyType.LEFT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 1  BodyType.RIGHT_FOOT      None         ShotHeightType.SHORT
# 2  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
# 3   BodyType.LEFT_FOOT      None          ShotHeightType.OVER
# 4  BodyType.RIGHT_FOOT      None  ShotHeightType.BOTTOM_THIRD
#
#              pressureType            shotNatureType       dist       ang  \
# 0                    None  ShotNatureType.PLACEMENT  13.152999  0.179112
# 1  PressureType.PRESSURED      ShotNatureType.POWER  33.992031  0.180536
# 2                    None  ShotNatureType.PLACEMENT  38.350833  0.169025
# 3                    None  ShotNatureType.PLACEMENT  39.591735  0.363845
# 4                    None  ShotNatureType.PLACEMENT  52.349883  0.153607
#
#      gol
# 0  False
# 1  False
# 2   True
# 3  False
# 4  False

# %% [markdown]
# Além do ângulo, é importante temos mais insighs sobre comos chutes são feitos e sua distribuição

# %%
df['body_part'].value_counts()
# Out:
# body_part
# BodyType.RIGHT_FOOT         768
# BodyType.LEFT_FOOT          466
# BodyType.HEAD               261
# BodyType.RIGHT_BACK_HEEL      4
# BodyType.LEFT_KNEE            4
# BodyType.RIGHT_SHIN           4
# BodyType.LEFT_SHOULDER        3
# BodyType.LEFT_SHIN            2
# BodyType.RIGHT_KNEE           2
# BodyType.RIGHT_THIGH          2
# BodyType.RIGHT_HAND           1
# BodyType.TWO_HAND_PALM        1
# Name: count, dtype: int64

# %% [markdown]
# Antes de continuar, vamos limpar um pouco o dado. A natureza de cabeceios é um pouco diferente de chutes. Vamos buscar analisar apenas chutes.

# %%
shots = df[
    df['body_part'].isin(
        [
            gandula.providers.pff.schema.event.BodyType.RIGHT_FOOT,
            gandula.providers.pff.schema.event.BodyType.LEFT_FOOT,
            gandula.providers.pff.schema.event.BodyType.RIGHT_KNEE,
            gandula.providers.pff.schema.event.BodyType.LEFT_KNEE,
            gandula.providers.pff.schema.event.BodyType.RIGHT_BACK_HEEL,
            gandula.providers.pff.schema.event.BodyType.LEFT_BACK_HEEL,
            gandula.providers.pff.schema.event.BodyType.RIGHT_THIGH,
            gandula.providers.pff.schema.event.BodyType.LEFT_THIGH,
        ]
    )
]

# %% [markdown]
# ### DESENVOLVIMENTO E TREINAMENTO DOS MODELOS

# %%
# SALVANDO BACKUP DOS DFs PARA NÃO TER QUE RODAR TODAS AS CÉLULAS NOVAMENTE PARA RETORNAR AO DF SEM ALTERAÇÃO

shots_raw = shots.copy()

df_raw = df.copy()

# %%
# RESTAURANDO OS DATAFRAMES SEM ALTERAÇÕES

df = df_raw.copy()
shots = shots_raw.copy()

# %%
# EXCLUSÃO DA COLUNA OUTCOME (VAZAMENTO DE DADOS) E SET_PIECE (TOTALMENTE NULA)

shots.drop(['outcome','set_piece'], axis=1, inplace=True)

df.drop(['outcome','set_piece'], axis=1, inplace=True)

# %%
# LENDO O ARQUIVO DE TESTE E EXTRAINDO A COLUNA DE ID

shotid_test = pd.read_csv('test.csv')
shotid_test = shotid_test[['shot_id']].astype('category')

# %%
# CRIANDO UMA COLUNA DE SHOT_ID NO DATASET (USANDO O FORMATO DE SUBMISSÃO - EVENT_ID + FRAME_ID) 

df['shot_id'] = (df['event_id'].astype(str) + '_' + df['frame_id'].astype(str))

df['shot_id'] = df['shot_id'].astype('category')

# %% [markdown]
# COMO OS DADOS DO GANDULA POSSUEM TODOS OS REGISTROS (INCLUINDO O DE TESTE), FAREI UM MERGE ENTRE O ARQUIVO COM OS DADOS DE TESTE E O DATASET COMPLETO ATRAVÉS DOS IDs. OS REGISTROS QUE ENCONTRAREM CORRESPONDENTE NO DATASET SÃO OS DE TESTES, OS OUTROS SERÃO USADOS PARA TREINO.
#
# ISSO SERÁ FEITO PARA NÃO CORRER RISCO DE TER VAZAMENTO DE DADOS, OU SEJA, USAR OS DADOS DE TESTE NO TREINAMENTO DO MODELO

# %%
# MERGE ENTRE O DATASET DO GANDULA E O DATASET DE TESTE

df_final = pd.merge(df,shotid_test, left_on=df['shot_id'], right_on=shotid_test['shot_id'], how='left', suffixes=('_left','_right'))

# TRANSFORMANDO OS REGISTROS NULOS (QUE NÃO ENCONTRARAM CORRESPONDENTE NO DATASET DE TESTE) COMO 0, O RESTO COMO 1

df_final['shot_id_right'] = np.where(df_final['shot_id_right'].isna(), 0, 1)

# ALTERANDO O NOME DAS COLUNAS 

df_final.rename(columns={'shot_id_right':'test',
                         'shot_id_left':'shot_id'}, inplace=True)

# EXCLUSÃO DE COLUNA DESNECESSÁRIA
df_final.drop('key_0', axis=1, inplace=True)

# %%
# FILTRAGEM DAS VARIÁVEIS PREDITORAS
#    EXCLUSÃO DAS COLUNAS REFERENTES AO ID + COLUNA GOL (VARIÁVEL A SER PREDITA) 

X = df_final.drop(['event_id','frame_id','shot_id','gol'], axis=1)

# TRATAMENTO DAS COLUNSA CATEGÓRICAS - TRANSFORMANDO CATEGORIAS EM VARIÁVEIS DUMMIES 

X_dummy = pd.get_dummies(X, prefix="", prefix_sep="")

# %%
# ARMAZENAMENTO DOS IDs DO CONJUNTO DE TREINO E TESTE PARA FACILITAR A SUBMISSÃO DA TENTATIVA NO FINAL

ids_test = df_final[df_final['test'] == 1][['event_id','frame_id','shot_id','test']]
ids_train = df_final[df_final['test'] == 0][['event_id','frame_id','shot_id','test']]

# FILTRAGEM DO CONJUNTO DE TREINO E TESTE - VARIÁVEL A SER PREDITA 

y_test = df_final[df_final['test'] == 1]['gol']
y_train = df_final[df_final['test'] == 0]['gol']

# FILTRAGEM DO CONJUNTO DE TREINO E TESTE - VARIÁVEIS PREDITORAS

X_test = X_dummy[X_dummy['test'] == 1].drop('test',axis=1)
X_train = X_dummy[X_dummy['test'] == 0].drop('test',axis=1)

# %% [markdown]
# TENTATIVA 3 DE SUBMISSÃO - XGBOOST

# %%
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

# INSTANCIANDO O MODELO

xgb = XGBClassifier()

# TREINAMENTO DO MODELO

xgb.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=20)
# Out:
# [0]	validation_0-logloss:0.35559	validation_1-logloss:0.35035
# [20]	validation_0-logloss:0.17426	validation_1-logloss:0.33957
# [40]	validation_0-logloss:0.11580	validation_1-logloss:0.35428
# [60]	validation_0-logloss:0.08097	validation_1-logloss:0.37287
# [80]	validation_0-logloss:0.06175	validation_1-logloss:0.39778
# [99]	validation_0-logloss:0.04806	validation_1-logloss:0.41791
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# PREDIÇÃO DO MOELO CRIADO

y_xgb = xgb.predict_proba(X_test)

# %%
# AVALIAÇÃO DOS RESULTADOS - ROC AUC 

roc_auc_score(y_test,y_xgb[:,1])
# Out:
# np.float64(0.7220843672456575)

# %%
# SALVANDO OS RESULTADOS NO FORMATO DA SUBMISSÃO

tentativa3 = pd.DataFrame({'shot_id': ids_test['shot_id'],
                           'xG': y_xgb[:,1]})

# %%
# SALVANDO OS RESULTADOS EM CSV PARA SUBMISSÃO NO KAGGLE

tentativa3.to_csv('tentativa3_xgb.csv', index=False)

# %% [markdown]
# TENTATIVA 4 DE SUBMISSÃO - XGBOOST COM `ALGUNS` HIPERPARÂMETROS OTIMIZADOS

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, roc_auc_score

# INSTANCIANDO O MODELO
xgb = XGBClassifier(use_label_encoder=False, eval_metric="auc")

# DEFINIÇÃO DE HIPERPARÂMETROS PARA SEREM TESTADOS
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.3],
    'max_depth': [3, 5, 7],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0]
}

# DETERMINAÇÃO DE UM SCORER COM A MÉTRICA DE AVALIAÇÃO DA COMPETIÇÃO
scorer = make_scorer(roc_auc_score, greater_is_better=True, needs_proba=True)

# CONFIGURANDO O OTIMIZADOR
grid_search = GridSearchCV(estimator=xgb, 
                           param_grid=param_grid, 
                           scoring=scorer,
                           cv=5,  # 5-fold cross-validation
                           verbose=3,  # visualização do progresso
                           n_jobs=-1  # uso de todos os núcleos disponíveis para acelerar o processo
                          )

# EXECUTANDO A OTIMIZAÇÃO
grid_search.fit(X_train, y_train)

# EXIBIÇÃO DOS MELHORES HIPERPARÂMETROS ENCONTRADOS
print(f"Melhores Parâmetros: {grid_search.best_params_}")
print(f"Melhor ROC AUC Score: {grid_search.best_score_:.4f}")

# %%
# INSTANCIANDO O MODELO COM OS MELHORES HIPERPARÂMETROS
final_model= XGBClassifier(**grid_search.best_params_)

# TREINAMENTO DO MODELO OTIMIZADO 
final_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# PREDIÇÃO DO MODELO OTIMIZADO
y_xgb = final_model.predict_proba(X_test)

# %%
# AVALIAÇÃO DOS RESULTADOS - ROC AUC 
roc_auc_score(y_test,y_xgb[:,1])
# Out:
# np.float64(0.7814229814850162)

# %%
# SALVANDO OS RESULTADOS NO FORMATO DA SUBMISSÃO
tentativa4 = pd.DataFrame({'shot_id': ids_test['shot_id'],
                           'xG': y_xgb[:,1]})

# %%
# SALVANDO OS RESULTADOS EM CSV PARA SUBMISSÃO NO KAGGLE
tentativa4.to_csv('tentativa4_xgb.csv', index=False)
